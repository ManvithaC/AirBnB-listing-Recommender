# %% [markdown]
# # Reviews Analysis

# %%
# Handle table-like data and matrices
import numpy as np
import pandas as pd

# import the libraries to deal with words in reviews column
# To filter the stopwords from text
from nltk.corpus import stopwords
import string
import nltk

# To filter the stopwords from text
nltk.download('stopwords')

# Punkt Sentence Tokenizer
# This tokenizer divides a text into a list of sentences, by using an unsupervised algorithm 
# to build a model for abbreviation words, collocations, and 
# words that start sentences. 
# It must be trained on a large collection of plaintext in the target language before it can be used.
nltk.download('punkt')

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# import the library for visualization - plotting
from matplotlib.pyplot import figure
import matplotlib
import matplotlib.pyplot as plt

# read the dataset into a data frame
df = pd.read_csv("reviews_detail.csv")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\manvi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\manvi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# drop the records with NaN values
reviews_df = df.dropna()

# reading the first few records because of computational limit
reviews_df = reviews_df.head(30000)

# %%
reviews=''

for index,row in reviews_df.iterrows():
    reviews = reviews + str(reviews_df['comments'])
    
reviews_data=nltk.word_tokenize(reviews)
string_punctuation = string.punctuation

# %%
# cache the stop words
existingStopWords = stopwords.words("english")
existingStopWords.append('the')

# remove unnecassary suffixes and prefixes
words_only = [s for s in words_only if s]

# join all the filtered and cleaned data
comments_filtered_data=' '.join(words_only)
comments_filtered_data = ' '.join([word.lower() 
                                   for word in comments_filtered_data.split() 
                                   if word not in existingStopWords])

# %%
# The below definition draws the word cloud withthe filtered data
def wordcloud_draw(data, color = 'black'):
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color=color,
                      width=3000,
                      height=2500
                     ).generate(data)
    plt.figure(1,figsize=(15, 15))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Wordcloud of Reviews

# %%
wordcloud_draw(comments_filtered_data)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We can conclude from the above word cloud that the top comment and top criteria is the "place". Location can also be seen as the top comment.
